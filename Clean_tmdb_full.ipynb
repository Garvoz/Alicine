# %%
import pandas as pd
import numpy as np

# %%
#Récupération de la BD :
link = "./BD/tmdb_full.csv"
df_tmdb = pd.read_csv(link, sep = ",")

# Création d'une copie :
df_tmdb_Clean = df_tmdb.copy()
# Out:
# C:\Users\ibtis\AppData\Local\Temp\ipykernel_29652\4100085175.py:3: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tmdb = pd.read_csv(link, sep = ",")

# %%
df_tmdb_Clean.shape
# Out:
# (309572, 25)

# %%
df_tmdb_Clean.sample(10)
# Out:
#         adult                     backdrop_path  budget  \
# 279177  False                               NaN       0
# 292809  False                               NaN       0
# 238512  False                               NaN       0
# 56793   False                               NaN       0
# 223796  False  /iXknBNcQ3Mb4rBC0OJAXebmbcAL.jpg       0
# 246423  False  /h520GmPXGKM2UT1R7TrQnbDIOAa.jpg       0
# 34481   False  /lS8RK2B74Ki226hafiaxgB8waJC.jpg       0
# 290004  False                               NaN       0
# 125587  False  /jO1sGLAtmFpridsTZEumsX4VcDS.jpg       0
# 192059  False  /ocA0EVI3GjWMDR0WVyxWnHPpb5p.jpg       0
#
#                                                  genres  \
# 279177                                               []
# 292809                                    ['Animation']
# 238512  ['Adventure', 'Animation', 'Comedy', 'Fantasy']
# 56793                                         ['Music']
# 223796     ['TV Movie', 'Crime', 'Mystery', 'Thriller']
# ...

# %%
df_tmdb_Clean.isna().sum()
# Out:
# adult                                0
# backdrop_path                   157812
# budget                               0
# genres                               0
# homepage                        265310
# id                                   0
# imdb_id                              0
# original_language                    0
# original_title                       0
# overview                         27060
# popularity                           0
# poster_path                      45413
# production_countries                 0
# release_date                      8233
# revenue                              0
# runtime                              0
# spoken_languages                     0
# status                               0
# tagline                         234999
# title                                0
# video                                0
# vote_average                         0
# vote_count                           0
# production_companies_name            0
# ...

# %%
df_tmdb_Clean[df_tmdb_Clean['release_date'].isna()]
# Out:
#         adult                     backdrop_path  budget  \
# 2909    False                               NaN       0
# 3769    False                               NaN       0
# 4055    False                               NaN       0
# 5319    False                               NaN       0
# 7465    False  /jQv3Zp22u6kDa4nlTvItpQDsrNy.jpg       0
# ...       ...                               ...     ...
# 308930  False                               NaN       0
# 308932  False                               NaN       0
# 309225  False                               NaN       0
# 309300  False                               NaN       0
# 309409  False                               NaN       0
#
#                                     genres homepage      id     imdb_id  \
# 2909                ['Action', 'Thriller']      NaN    5492  tt12598606
# 3769                             ['Drama']      NaN    8317   tt4032552
# 4055                          ['Thriller']      NaN    8947   tt0473472
# ...

# %%
df_tmdb_Clean['release_date']=pd.to_datetime(df_tmdb_Clean['release_date'])

# %%
df_tmdb_Clean['release_date'].describe()
# Out:
# count                           301339
# mean     1994-05-20 08:38:07.645475712
# min                1874-12-09 00:00:00
# 25%                1979-01-03 00:00:00
# 50%                2005-06-16 00:00:00
# 75%                2015-12-12 00:00:00
# max                2028-12-20 00:00:00
# Name: release_date, dtype: object

# %%
df_tmdb_Clean[df_tmdb_Clean['release_date'] > '2024-01-01']
# Out:
#         adult                     backdrop_path     budget  \
# 13496   False                               NaN          0
# 13550   False  /43V8ES6Hfx6d1knUxjLm0Fn85BT.jpg     100000
# 13565   False                               NaN          0
# 13638   False                               NaN          0
# 13666   False                               NaN          0
# ...       ...                               ...        ...
# 154377  False                               NaN        450
# 156310  False                               NaN          0
# 157608  False                               NaN       6688
# 203424  False                               NaN  250000000
# 246554  False                               NaN  250000000
#
#                                                    genres  \
# 13496                       ['Comedy', 'Crime', 'Horror']
# 13550                       ['Action', 'Science Fiction']
# 13565                                        ['Thriller']
# ...
