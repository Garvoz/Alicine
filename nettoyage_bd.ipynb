# %%
import pandas as pd

# %%
link1 = "./BD/name.basics.tsv.gz"
link2 = "./BD/title.akas.tsv.gz"
link3 = "./BD/title.basics.tsv.gz"
link4 = "./BD/title.crew.tsv.gz"
link5 = "./BD/title.episode.tsv.gz"
link6 = "./BD/title.principals.tsv.gz"
link7 = "./BD/title.ratings.tsv.gz"
link8 = "./BD/tmdb_full.csv"
df_basic_name = pd.read_csv(link1, sep = "\t", compression = "gzip", nrows = 1000)
df_t_akas = pd.read_csv(link2, sep = "\t", compression = "gzip", nrows = 1000)
df_t_basics = pd.read_csv(link3, sep = "\t", compression = "gzip", nrows = 1000)
df_t_crew = pd.read_csv(link4, sep = "\t", compression = "gzip", nrows = 1000)
df_t_episode = pd.read_csv(link5, sep = "\t", compression = "gzip", nrows = 1000)
df_t_principals = pd.read_csv(link6, sep = "\t", compression = "gzip", nrows = 1000)
df_t_ratings = pd.read_csv(link7, sep = "\t", compression = "gzip", nrows = 1000)
df_tmdb = pd.read_csv(link8, nrows = 1000)

# %%
df_basic_name
# Out:
#         nconst      primaryName birthYear deathYear  \
# 0    nm0000001     Fred Astaire      1899      1987
# 1    nm0000002    Lauren Bacall      1924      2014
# 2    nm0000003  Brigitte Bardot      1934        \N
# 3    nm0000004     John Belushi      1949      1982
# 4    nm0000005   Ingmar Bergman      1918      2007
# ..         ...              ...       ...       ...
# 995  nm0000997       Gary Busey      1944        \N
# 996  nm0000998       Jake Busey      1971        \N
# 997  nm0000999      Red Buttons      1919      2006
# 998  nm0001000        Tom Byron      1961        \N
# 999  nm0001001       James Caan      1940      2022
#
#                       primaryProfession  \
# 0          actor,miscellaneous,producer
# 1    actress,soundtrack,archive_footage
# 2     actress,music_department,producer
# 3         actor,writer,music_department
# 4                 writer,director,actor
# ..                                  ...
# 995             actor,producer,composer
# 996     actor,producer,music_department
# 997          actor,writer,miscellaneous
# 998             actor,director,producer
# 999               actor,director,stunts
#
#                               knownForTitles
# 0    tt0050419,tt0072308,tt0053137,tt0027125
# 1    tt0037382,tt0075213,tt0117057,tt0038355
# 2    tt0057345,tt0049189,tt0056404,tt0054452
# 3    tt0072562,tt0077975,tt0080455,tt0078723
# 4    tt0050986,tt0069467,tt0050976,tt0083922
# ..                                       ...
# 995  tt0077280,tt0093409,tt0102685,tt0105690
# 996  tt0120201,tt0309698,tt0116365,tt0120660
# 997  tt0076538,tt0069113,tt0050933,tt0056059
# 998  tt2059288,tt0178845,tt0097039,tt0148895
# 999  tt0083190,tt0073631,tt0100157,tt0068646
#
# [1000 rows x 6 columns]

# %% [markdown]
#     nconst (string) - alphanumeric unique identifier of the name/person
#     primaryName (string)– name by which the person is most often credited
#     birthYear – in YYYY format
#     deathYear – in YYYY format if applicable, else ‘\N’
#     primaryProfession (array of strings)– the top-3 professions of the person
#     knownForTitles (array of tconsts) – titles the person is known for

# %%
df = df_t_akas[(df_t_akas['region'] == 'FR') | (df_t_akas['region'] == 'US') | (df_t_akas['region'] == r'\N')]
len(df['titleId'].unique())
a= set(df['titleId'].unique())
b = set(df_t_akas['titleId'].unique())
print(b-a)
# Out:
# set()

# %%
df_t_akas
# Out:
#        titleId  ordering                      title region language  \
# 0    tt0000001         1                 Carmencita     \N       \N
# 1    tt0000001         2                 Carmencita     DE       \N
# 2    tt0000001         3                 Carmencita     US       \N
# 3    tt0000001         4  Carmencita - spanyol tánc     HU       \N
# 4    tt0000001         5                 Καρμενσίτα     GR       \N
# ..         ...       ...                        ...    ...      ...
# 995  tt0000218         2              A Dreyfus-ügy     HU       \N
# 996  tt0000218         3         Die Affäre Dreyfus     DE       \N
# 997  tt0000218         4           Dreyfusova aféra     CZ       \N
# 998  tt0000218         5            El caso Dreyfus     ES       \N
# 999  tt0000218         6          L'affaire Dreyfus     FR       \N
#
#            types     attributes  isOriginalTitle
# 0       original             \N                1
# 1             \N  literal title                0
# 2    imdbDisplay             \N                0
# 3    imdbDisplay             \N                0
# 4    imdbDisplay             \N                0
# ..           ...            ...              ...
# 995  imdbDisplay             \N                0
# 996           \N             \N                0
# 997  imdbDisplay             \N                0
# 998  imdbDisplay             \N                0
# 999  imdbDisplay             \N                0
#
# [1000 rows x 8 columns]

# %% [markdown]
#     titleId (string) - a tconst, an alphanumeric unique identifier of the title
#     ordering (integer) – a number to uniquely identify rows for a given titleId
#     title (string) – the localized title
#     region (string) - the region for this version of the title
#     language (string) - the language of the title
#     types (array) - Enumerated set of attributes for this alternative title. One or more of the following: “alternative”, “dvd”, “festival”, “tv”, “video”, “working”, “original”, “imdbDisplay”. New values may be added in the future without warning
#     attributes (array) - Additional terms to describe this alternative title, not enumerated
#     isOriginalTitle (boolean) – 0: not original title; 1: original title

# %%
df_t_basics
# Out:
#         tconst titleType                                       primaryTitle  \
# 0    tt0000001     short                                         Carmencita
# 1    tt0000002     short                             Le clown et ses chiens
# 2    tt0000003     short                                       Poor Pierrot
# 3    tt0000004     short                                        Un bon bock
# 4    tt0000005     short                                   Blacksmith Scene
# ..         ...       ...                                                ...
# 995  tt0001007     movie                       La primera y segunda casetas
# 996  tt0001008     short                          The Prince and the Pauper
# 997  tt0001009     short             Princess Nicotine; or, The Smoke Fairy
# 998  tt0001010     movie  Protección de un convoy de víveres en el puent...
# 999  tt0001011     short                                   The Prussian Spy
#
#                                          originalTitle  isAdult startYear  \
# 0                                           Carmencita        0      1894
# 1                               Le clown et ses chiens        0      1892
# 2                                       Pauvre Pierrot        0      1892
# 3                                          Un bon bock        0      1892
# 4                                     Blacksmith Scene        0      1893
# ..                                                 ...      ...       ...
# 995                       La primera y segunda casetas        0      1909
# 996                          The Prince and the Pauper        0      1909
# 997             Princess Nicotine; or, The Smoke Fairy        0      1909
# 998  Protección de un convoy de víveres en el puent...        0      1909
# 999                                   The Prussian Spy        0      1909
#
#     endYear runtimeMinutes                    genres
# 0        \N              1         Documentary,Short
# 1        \N              5           Animation,Short
# 2        \N              5  Animation,Comedy,Romance
# 3        \N             12           Animation,Short
# 4        \N              1              Comedy,Short
# ..      ...            ...                       ...
# 995      \N             \N                        \N
# 996      \N             \N                     Short
# 997      \N              5      Comedy,Fantasy,Short
# 998      \N             \N                        \N
# 999      \N              5               Drama,Short
#
# [1000 rows x 9 columns]

# %% [markdown]
#     tconst (string) - alphanumeric unique identifier of the title
#     titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
#     primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
#     originalTitle (string) - original title, in the original language
#     isAdult (boolean) - 0: non-adult title; 1: adult title
#     startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
#     endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
#     runtimeMinutes – primary runtime of the title, in minutes
#     genres (string array) – includes up to three genres associated with the title

# %%
df_t_crew
# Out:
#         tconst  directors              writers
# 0    tt0000001  nm0005690                   \N
# 1    tt0000002  nm0721526                   \N
# 2    tt0000003  nm0721526                   \N
# 3    tt0000004  nm0721526                   \N
# 4    tt0000005  nm0005690                   \N
# ..         ...        ...                  ...
# 995  tt0001007  nm0185426                   \N
# 996  tt0001008  nm0205986  nm0205986,nm0878494
# 997  tt0001009  nm0085865                   \N
# 998  tt0001010  nm0185426                   \N
# 999  tt0001011  nm0000428            nm0000428
#
# [1000 rows x 3 columns]

# %% [markdown]
#     tconst (string) - alphanumeric unique identifier of the title
#     directors (array of nconsts) - director(s) of the given title
#     writers (array of nconsts) – writer(s) of the given title

# %%
df_t_episode
# Out:
#         tconst parentTconst seasonNumber episodeNumber
# 0    tt0031458   tt32857063           \N            \N
# 1    tt0041951    tt0041038            1             9
# 2    tt0042816    tt0989125            1            17
# 3    tt0042889    tt0989125           \N            \N
# 4    tt0043426    tt0040051            3            42
# ..         ...          ...          ...           ...
# 995  tt0077496    tt0068067            7             3
# 996  tt0077515    tt0075471            1            10
# 997  tt0077561    tt0958967            1            16
# 998  tt0077565    tt0165593           13             3
# 999  tt0077568    tt0077011            1             0
#
# [1000 rows x 4 columns]

# %% [markdown]
#     tconst (string) - alphanumeric identifier of episode
#     parentTconst (string) - alphanumeric identifier of the parent TV Series
#     seasonNumber (integer) – season number the episode belongs to
#     episodeNumber (integer) – episode number of the tconst in the TV series

# %%
df_t_principals
# Out:
#         tconst  ordering     nconst         category                      job  \
# 0    tt0000001         1  nm1588970             self                       \N
# 1    tt0000001         2  nm0005690         director                       \N
# 2    tt0000001         3  nm0005690         producer                 producer
# 3    tt0000001         4  nm0374658  cinematographer  director of photography
# 4    tt0000002         1  nm0721526         director                       \N
# ..         ...       ...        ...              ...                      ...
# 995  tt0000465         5  nm0243651            actor                       \N
# 996  tt0000466         1  nm0349785         director                       \N
# 997  tt0000467         1  nm0349785         director                       \N
# 998  tt0000468         1  nm0349785         director                       \N
# 999  tt0000469         1  nm0808310         director                       \N
#
#     characters
# 0     ["Self"]
# 1           \N
# 2           \N
# 3           \N
# 4           \N
# ..         ...
# 995  ["Extra"]
# 996         \N
# 997         \N
# 998         \N
# 999         \N
#
# [1000 rows x 6 columns]

# %% [markdown]
#     tconst (string) - alphanumeric unique identifier of the title
#     ordering (integer) – a number to uniquely identify rows for a given titleId
#     nconst (string) - alphanumeric unique identifier of the name/person
#     category (string) - the category of job that person was in
#     job (string) - the specific job title if applicable, else ‘\N’
#     characters (string) - the name of the character played if applicable, else ‘\N’

# %%
df_t_ratings
# Out:
#         tconst  averageRating  numVotes
# 0    tt0000001            5.7      2101
# 1    tt0000002            5.6       282
# 2    tt0000003            6.5      2121
# 3    tt0000004            5.4       182
# 4    tt0000005            6.2      2852
# ..         ...            ...       ...
# 995  tt0001973            6.0       308
# 996  tt0001978            5.8        62
# 997  tt0001987            6.1        24
# 998  tt0001989            5.7        17
# 999  tt0001993            4.1        21
#
# [1000 rows x 3 columns]

# %% [markdown]
#     tconst (string) - alphanumeric unique identifier of the title
#     averageRating – weighted average of all the individual user ratings
#     numVotes - number of votes the title has received

# %%
df_tmdb
# Out:
#      adult                     backdrop_path    budget  \
# 0    False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg         0
# 1    False                               NaN         0
# 2    False  /uJlc4aNPF3Y8yAqahJTKBwgwPVW.jpg         0
# 3    False  /hQ4pYsIbP22TMXOUdSfC2mjWrO0.jpg         0
# 4    False  /l94l89eMmFKh7na2a1u5q67VgNx.jpg         0
# ..     ...                               ...       ...
# 995  False  /i7Z2hHvm0bKEFB4EvXpk6kFYDyV.jpg         0
# 996  False  /u49EZzHvGCNrHdQxkc3hhLmQEPP.jpg  16000000
# 997  False  /osVUxxcXnJd9tqSRZBk4RxVl0As.jpg  10000000
# 998  False  /oCGXjcyvJ110utQrtHGJn4fethQ.jpg         0
# 999  False  /aNgiRVe7fDrrxsfWzPh6fN1V39R.jpg         0
#
#                                           genres  \
# 0                                     ['Comedy']
# 1                                  ['Adventure']
# 2                           ['Drama', 'Romance']
# 3                   ['Drama', 'Comedy', 'Crime']
# 4                 ['Drama', 'Comedy', 'Romance']
# ..                                           ...
# 995                         ['Drama', 'Romance']
# 996  ['Drama', 'Thriller', 'Crime', 'Adventure']
# 997                                   ['Comedy']
# 998                         ['Drama', 'Romance']
# 999               ['Drama', 'Comedy', 'Romance']
#
#                                            homepage    id    imdb_id  \
# 0                                               NaN  3924  tt0029927
# 1                                               NaN  6124  tt0011436
# 2                                               NaN  8773  tt0055747
# 3                                               NaN     2  tt0094675
# 4                                               NaN     3  tt0092149
# ..                                              ...   ...        ...
# 995                                             NaN  1540  tt0381690
# 996                                             NaN  1541  tt0103074
# 997                                             NaN  1542  tt0151804
# 998      http://emmas-glueck.pandorafilmverleih.de/  1543  tt0424992
# 999  http://www.foxsearchlight.com/imaginemeandyou/  1544  tt0421994
#
#     original_language        original_title  \
# 0                  en               Blondie
# 1                  de   Der Mann ohne Namen
# 2                  fr   L'Amour à vingt ans
# 3                  fi                 Ariel
# 4                  fi  Varjoja paratiisissa
# ..                ...                   ...
# 995                fr           Vers le sud
# 996                en       Thelma & Louise
# 997                en          Office Space
# 998                de           Emmas Glück
# 999                en      Imagine Me & You
#
#                                               overview  ...  runtime  \
# 0    Blondie and Dagwood are about to celebrate the...  ...       70
# 1                                                  NaN  ...      420
# 2    Love at Twenty unites five directors from five...  ...      110
# 3    Taisto Kasurinen is a Finnish coal miner whose...  ...       73
# 4    An episode in the life of Nikander, a garbage ...  ...       76
# ..                                                 ...  ...      ...
# 995  A story of three female tourists who visit Hai...  ...      108
# 996  Whilst on a short weekend getaway, Louise shoo...  ...      130
# 997  A depressed white-collar worker tries hypnothe...  ...       90
# 998  Upon being informed that he is fatally ill wit...  ...      103
# 999  During her wedding ceremony, Rachel notices Lu...  ...       93
#
#                    spoken_languages    status  \
# 0                            ['en']  Released
# 1                                []  Released
# 2    ['it', 'ja', 'pl', 'fr', 'de']  Released
# 3                            ['fi']  Released
# 4                            ['en']  Released
# ..                              ...       ...
# 995              ['fr', 'ht', 'en']  Released
# 996                          ['en']  Released
# 997                          ['en']  Released
# 998                          ['de']  Released
# 999                          ['en']  Released
#
#                                                tagline  \
# 0    The favorite comic strip of millions at last o...
# 1                                                  NaN
# 2                 The Intimate Secrets of Young Lovers
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996             Somebody said get a life… so they did.
# 997                                        Work sucks.
# 998                                                NaN
# 999                              There goes the bride.
#
#                              title  video vote_average vote_count  \
# 0                          Blondie  False        7.214          7
# 1    Peter Voss, Thief of Millions  False        0.000          0
# 2                   Love at Twenty  False        6.700         41
# 3                            Ariel  False        7.046        248
# 4              Shadows in Paradise  False        7.182        269
# ..                             ...    ...          ...        ...
# 995                  Heading South  False        5.600         27
# 996                Thelma & Louise  False        7.569       2916
# 997                   Office Space  False        7.376       2544
# 998                   Emma's Bliss  False        6.614         35
# 999               Imagine Me & You  False        7.579        880
#
#                              production_companies_name  \
# 0                                ['Columbia Pictures']
# 1                                                   []
# 2    ['Ulysse Productions', 'Unitec Films', 'Cinese...
# 3                        ['Villealfa Filmproductions']
# 4                        ['Villealfa Filmproductions']
# ..                                                 ...
# 995                                  ['Haut et Court']
# 996  ['Star Partners III Ltd.', 'Metro-Goldwyn-Maye...
# 997               ['Cubicle Inc.', '20th Century Fox']
# 998                                            ['ARD']
# 999  ['BBC Film', 'Filmstiftung Nordrhein-Westfalen...
#
#                           production_companies_country
# 0                                               ['US']
# 1                                                   []
# 2               ['', 'NZ', 'IT', 'JP', 'DE', 'PL', '']
# 3                                               ['FI']
# 4                                               ['FI']
# ..                                                 ...
# 995                                             ['FR']
# 996                                   ['', 'US', 'US']
# 997                                         ['', 'US']
# 998                                             ['DE']
# 999  ['GB', 'DE', 'GB', 'GB', 'US', '', '', 'DE', '...
#
# [1000 rows x 25 columns]

# %% [markdown]
#     adult : Un champ indiquant si le film est destiné à un public adulte, avec les valeurs “true” ou “false”.
#     backdrop_path : Le chemin d’accès à l’image de fond associée au film, utilisée à des fins de marketing et de promotion.
#     budget : Le budget du film, généralement en dollars ou dans la devise de référence.
#     genres : Les genres du film, tels que “Action,” “Comedy,” “Science Fiction,” etc.
#     homepage : L’URL de la page d’accueil officielle du film.
#     id : L’ID du film dans la base de données TMDB, utilisé pour identifier de manière unique chaque film.
#     imdb_id : L’ID IMDB du film, un identifiant unique dans la base de données IMDB.
#     original_language : La langue originale du film.
#     original_title : Le titre original du film dans sa langue d’origine.
#     overview : Une brève description ou un résumé du film.
#     popularity : Un indicateur de la popularité du film.
#     poster_path : Le chemin d’accès à l’affiche du film, utilisée à des fins de marketing.
#     production_countries : Les pays de production du film, avec la possibilité d’avoir plusieurs pays listés.
#     release_date : La date de sortie du film.
#     revenue : Le chiffre d’affaires généré par le film, généralement en dollars ou dans la devise de référence.
#     runtime : La durée en minutes du film.
#     spoken_languages : Les langues parlées dans le film.
#     status : Le statut du film, par exemple, “Released” ou “In Production”.
#     tagline : Une phrase ou un slogan court résumant le film, utilisée à des fins marketing.
#     title : Le titre du film.
#     video : Un indicateur booléen indiquant si le film a une bande-annonce vidéo (“true” ou “false”).
#     vote_average : La note moyenne attribuée au film par les utilisateurs ou les critiques.
#     vote_count : Le nombre de votes ou de critiques reçus par le film.
#     production_companies_name : Le nom des sociétés de production associées au film.
#     production_companies_country : Le pays d’origine des sociétés de production associées au film.
