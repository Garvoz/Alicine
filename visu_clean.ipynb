# %%
import pandas as pd

# %%
link1 = "./BD/df_basic_name_clean.csv"
link2 = "./BD/df_t_akas_clean.csv"
link3 = "./BD/df_t_basics_clean.csv"
link4 = "./BD/df_t_crew_clean.csv"
link5 = "./BD/df_t_episode_clean.csv"
link6 = "./BD/df_t_principals_clean.csv"
link7 = "./BD/df_t_ratings_clean.csv"

# %%
df_basic_name = pd.read_csv(link1)
df_basic_name
# Out:
#             nconst       primaryName  birthYear  deathYear  \
# 0        nm0000001      Fred Astaire     1899.0     1987.0
# 1        nm0000002     Lauren Bacall     1924.0     2014.0
# 2        nm0000003   Brigitte Bardot     1934.0        NaN
# 3        nm0000004      John Belushi     1949.0     1982.0
# 4        nm0000005    Ingmar Bergman     1918.0     2007.0
# ...            ...               ...        ...        ...
# 6073212  nm9993700        Sexy Angel        NaN        NaN
# 6073213  nm9993701  Sanjai Kuriakose        NaN        NaN
# 6073214  nm9993703   James Craigmyle        NaN        NaN
# 6073215  nm9993708        Eli Bevins        NaN        NaN
# 6073216  nm9993709         Lu Bevins        NaN        NaN
#
#                                     primaryProfession  \
# 0              ['actor', 'miscellaneous', 'producer']
# 1        ['actress', 'soundtrack', 'archive_footage']
# 2         ['actress', 'music_department', 'producer']
# 3             ['actor', 'writer', 'music_department']
# 4                     ['writer', 'director', 'actor']
# ...                                               ...
# 6073212                                   ['actress']
# 6073213                                     ['actor']
# 6073214                                     ['actor']
# 6073215            ['producer', 'director', 'writer']
# 6073216            ['producer', 'director', 'writer']
#
#                                             knownForTitles
# 0        ['tt0050419', 'tt0072308', 'tt0053137', 'tt002...
# 1        ['tt0037382', 'tt0075213', 'tt0117057', 'tt003...
# 2        ['tt0057345', 'tt0049189', 'tt0056404', 'tt005...
# 3        ['tt0072562', 'tt0077975', 'tt0080455', 'tt007...
# 4        ['tt0050986', 'tt0069467', 'tt0050976', 'tt008...
# ...                                                    ...
# 6073212                                      ['tt7523066']
# 6073213                                      ['tt8736744']
# 6073214  ['tt11212278', 'tt6914160', 'tt10627062', 'tt6...
# 6073215  ['tt11702702', 'tt14508814', 'tt11772904', 'tt...
# 6073216  ['tt17717854', 'tt11772904', 'tt11772812', 'tt...
#
# [6073217 rows x 6 columns]

# %%
df_t_akas = pd.read_csv(link2)
df_t_akas
# Out:
#             titleId                                              title
# 0         tt0000001  ['Carmencita', 'Carmencita', 'Carmencita', 'Ca...
# 1         tt0000002  ['Le clown et ses chiens', 'A bohóc és kutyái'...
# 2         tt0000003  ['Pauvre Pierrot', '哀れなピエロ', 'Poor Pierrot', '...
# 3         tt0000004  ['Un bon bock', 'A Good Beer', 'Egy jó pohár s...
# 4         tt0000005  ['Blacksmith Scene', "The Blacksmith's Forge",...
# ...             ...                                                ...
# 11242903  tt9916848  ['Episode #3.17', 'Episódio #3.17', 'एपिसोड #3...
# 11242904  tt9916850  ['Episode #3.19', 'Episódio #3.19', 'एपिसोड #3...
# 11242905  tt9916852  ['Episode #3.20', 'Episódio #3.20', 'एपिसोड #3...
# 11242906  tt9916856                           ['The Wind', 'The Wind']
# 11242907  tt9916880                      ['Horrid Henry Knows It All']
#
# [11242908 rows x 2 columns]

# %%
df_t_basics = pd.read_csv(link3)
df_t_basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short               Poor Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 11265984  tt9916848  tvEpisode              Episode #3.17
# 11265985  tt9916850  tvEpisode              Episode #3.19
# 11265986  tt9916852  tvEpisode              Episode #3.20
# 11265987  tt9916856      short                   The Wind
# 11265988  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle  isAdult  startYear  endYear  \
# 0                        Carmencita        0     1894.0      NaN
# 1            Le clown et ses chiens        0     1892.0      NaN
# 2                    Pauvre Pierrot        0     1892.0      NaN
# 3                       Un bon bock        0     1892.0      NaN
# 4                  Blacksmith Scene        0     1893.0      NaN
# ...                             ...      ...        ...      ...
# 11265984              Episode #3.17        0     2009.0      NaN
# 11265985              Episode #3.19        0     2010.0      NaN
# 11265986              Episode #3.20        0     2010.0      NaN
# 11265987                   The Wind        0     2015.0      NaN
# 11265988  Horrid Henry Knows It All        0     2014.0      NaN
#
#           runtimeMinutes                                genres
# 0                    1.0              ['Documentary', 'Short']
# 1                    5.0                ['Animation', 'Short']
# 2                    5.0    ['Animation', 'Comedy', 'Romance']
# 3                   12.0                ['Animation', 'Short']
# 4                    1.0                   ['Comedy', 'Short']
# ...                  ...                                   ...
# 11265984             NaN         ['Action', 'Drama', 'Family']
# 11265985             NaN         ['Action', 'Drama', 'Family']
# 11265986             NaN         ['Action', 'Drama', 'Family']
# 11265987            27.0                             ['Short']
# 11265988            10.0  ['Adventure', 'Animation', 'Comedy']
#
# [11265989 rows x 9 columns]

# %%
df_t_crew = pd.read_csv(link4)
df_t_crew
# Out:
#              tconst       directors  \
# 0         tt0000001   ['nm0005690']
# 1         tt0000002   ['nm0721526']
# 2         tt0000003   ['nm0721526']
# 3         tt0000004   ['nm0721526']
# 4         tt0000005   ['nm0005690']
# ...             ...             ...
# 10600625  tt9916848   ['nm1485677']
# 10600626  tt9916850   ['nm1485677']
# 10600627  tt9916852   ['nm1485677']
# 10600628  tt9916856  ['nm10538645']
# 10600629  tt9916880   ['nm0996406']
#
#                                                     writers
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 10600625  ['nm9187127', 'nm1485677', 'nm9826385', 'nm929...
# 10600626  ['nm9187127', 'nm1485677', 'nm9826385', 'nm162...
# 10600627  ['nm9187127', 'nm1485677', 'nm9826385', 'nm929...
# 10600628                                      ['nm6951431']
# 10600629                         ['nm1482639', 'nm2586970']
#
# [10600630 rows x 3 columns]

# %%
df_t_episode = pd.read_csv(link5)
df_t_episode
# Out:
#             tconst parentTconst  IdSerie
# 0        tt0031458   tt32857063     True
# 1        tt0041951    tt0041038     True
# 2        tt0042816    tt0989125     True
# 3        tt0042889    tt0989125     True
# 4        tt0043426    tt0040051     True
# ...            ...          ...      ...
# 8654981  tt9916846    tt1289683     True
# 8654982  tt9916848    tt1289683     True
# 8654983  tt9916850    tt1289683     True
# 8654984  tt9916852    tt1289683     True
# 8654985  tt9916880    tt0985991     True
#
# [8654986 rows x 3 columns]

# %%
df_t_principals = pd.read_csv(link6)
df_t_principals
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_t_principals = pd.read_csv(link6)
#       2 df_t_principals
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1968, in TextFileReader.read(self, nrows)
#    1965     else:
#    1966         new_col_dict = col_dict
# -> 1968     df = DataFrame(
#    1969         new_col_dict,
#    1970         columns=columns,
#    1971         index=index,
#    1972         copy=not using_copy_on_write(),
#    1973     )
#    1975     self._currow += new_rows
#    1976 return df
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:629, in _homogenize(data, index, dtype)
#     626         val = dict(val)
#     627     val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 629 val = sanitize_array(val, index, dtype=dtype, copy=False)
#     630 com.require_length_match(val, index)
#     631 refs.append(None)
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File c:\Users\Antoine\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1190, in maybe_infer_to_datetimelike(value)
#    1185     return value
#    1187 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1188 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1189 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1190 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1191     value,
#    1192     # Here we do not convert numeric dtypes, as if we wanted that,
#    1193     #  numpy would have done it for us.
#    1194     convert_numeric=False,
#    1195     convert_non_numeric=True,
#    1196     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1197 )
#
# File lib.pyx:2542, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 83.7 MiB for an array with shape (87742965,) and data type uint8

# %%
df_t_ratings = pd.read_csv(link7)
df_t_ratings
